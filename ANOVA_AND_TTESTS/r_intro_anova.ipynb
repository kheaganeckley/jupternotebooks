# %% [markdown]
# <h1>ANOVA</h1>
# <p>
# this is a special case of regression
# </p>

# %%
library(tidyverse)

# %%
library(readr)
df <- read_csv("/home/kheagan/Documents/programing/juypter/notebooks/TSA/TSA/UDEMY_TSA_FINAL/Data/macrodata.csv",col_names=TRUE)
head(df)
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_character(),
#   year = col_double(),
#   quarter = col_double(),
#   realgdp = col_double(),
#   realcons = col_double(),
#   realinv = col_double(),
#   realgovt = col_double(),
#   realdpi = col_double(),
#   cpi = col_double(),
#   m1 = col_double(),
#   tbilrate = col_double(),
#   unemp = col_double(),
#   pop = col_double(),
#   infl = col_double(),
#   realint = col_double()
# )
#   X1         year quarter realgdp  realcons realinv realgovt realdpi cpi
# 1 3/31/1959  1959 1       2710.349 1707.4   286.898 470.045  1886.9  28.98
# 2 6/30/1959  1959 2       2778.801 1733.7   310.859 481.301  1919.7  29.15
# 3 9/30/1959  1959 3       2775.488 1751.8   289.226 491.260  1916.4  29.35
# 4 12/31/1959 1959 4       2785.204 1753.7   299.356 484.052  1931.3  29.37
# 5 3/31/1960  1960 1       2847.699 1770.5   331.722 462.199  1955.5  29.54
# ...

# %%
library(broom)
model <- lm(realgdp~as.factor(quarter),df)
tidy(model)
# Out:
#   term                estimate   std.error statistic   p.value
# 1 (Intercept)         7168.95306 453.5305  15.80699373 5.348293e-37
# 2 as.factor(quarter)2   58.71339 641.3889   0.09154101 9.271548e-01
# 3 as.factor(quarter)3  109.26161 641.3889   0.17035157 8.649067e-01
# 4 as.factor(quarter)4   40.67400 644.5879   0.06310078 9.497496e-01

# %%
plot(model)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
