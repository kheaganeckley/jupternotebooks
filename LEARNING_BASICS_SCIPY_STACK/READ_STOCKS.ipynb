# %%
import quandl 
import pandas as pd

# %%
df= quandl.get("CHRIS/MGEX_MW5", authtoken="E6i81mswnSBokt3ti9_B")
df.head()
# Out:
#              Open   High    Low    Last  Volume  Open Interest
# Date
# 1996-03-20  458.0  465.0  456.5  461.00     0.0            0.0
# 1996-03-21  461.5  462.5  460.5  461.00     0.0            0.0
# 1996-03-22  461.5  461.5  459.5  459.75     0.0            0.0
# 1996-03-25  464.5  470.0  464.5  468.50     0.0            0.0
# 1996-03-26  469.0  485.5  469.0  481.75     0.0            0.0

# %%
df['Open'].plot.line(title='kheagans first plot', lw=0.5, figsize=(10,10))

# %%
df.plot.line(figsize=(10,10))
