# %%
library(tidyverse)

# %%
library(readr)
df  <- read_csv("/home/kheagan/Documents/programing/juypter/notebooks/TSA/TSA/UDEMY_TSA_FINAL/Data/macrodata.csv")
head(df)
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   X1 = col_character(),
#   year = col_double(),
#   quarter = col_double(),
#   realgdp = col_double(),
#   realcons = col_double(),
#   realinv = col_double(),
#   realgovt = col_double(),
#   realdpi = col_double(),
#   cpi = col_double(),
#   m1 = col_double(),
#   tbilrate = col_double(),
#   unemp = col_double(),
#   pop = col_double(),
#   infl = col_double(),
#   realint = col_double()
# )
#   X1         year quarter realgdp  realcons realinv realgovt realdpi cpi
# 1 3/31/1959  1959 1       2710.349 1707.4   286.898 470.045  1886.9  28.98
# 2 6/30/1959  1959 2       2778.801 1733.7   310.859 481.301  1919.7  29.15
# 3 9/30/1959  1959 3       2775.488 1751.8   289.226 491.260  1916.4  29.35
# 4 12/31/1959 1959 4       2785.204 1753.7   299.356 484.052  1931.3  29.37
# 5 3/31/1960  1960 1       2847.699 1770.5   331.722 462.199  1955.5  29.54
# ...

# %%
library(broom)
model1 = lm(realgdp ~ year + m1,df)
tidy(model1)
# Out:
#   term        estimate      std.error    statistic  p.value
# 1 (Intercept) -2.568966e+05 20233.151581 -12.696818 1.780570e-27
# 2 year         1.322034e+02    10.307723  12.825664 7.154834e-28
# 3 m1           2.758628e+00     0.332467   8.297448 1.559658e-14

# %%
plot(model1)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
